# %% [markdown]
# # Análise NBA

# %% [markdown]
# ### Bibliotecas a serem importadas

# %%
import pandas as pd #Biblioteca onde iremos importar e ler os dados analisados
import matplotlib.pyplot as plt #Biblioteca responsável por gerar os gráficos
import numpy as np #Biblioteca que irá ajudar a lidar com os números

# %% [markdown]
# ### De onde iremos buscar as informações

# %%
dados = pd.read_excel('DatabaseNBA.xls')

# %% [markdown]
# ### Teste para ver se a base está rodando

# %%
dados.head()
# Out:
#    Rk                   Player  Age Team Pos   G  GS    MP    FG   FGA  ...
# 0   1              Joel Embiid   29  PHI   C  39  39  33.6  11.5  21.8  ...  \
# 1   2              Luka Dončić   24  DAL  PG  70  70  37.5  11.5  23.6  ...
# 2   3    Giannis Antetokounmpo   29  MIL  PF  73  73  35.2  11.5  18.8  ...
# 3   4  Shai Gilgeous-Alexander   25  OKC  PG  75  75  34.0  10.6  19.8  ...
# 4   5            Jalen Brunson   27  NYK  PG  77  77  35.4  10.3  21.4  ...
#
#    ORB  DRB   TRB  AST  STL  BLK  TOV   PF   PTS                        Awards
# 0  2.4  8.6  11.0  5.6  1.2  1.7  3.8  2.9  34.7                            AS
# 1  0.8  8.4   9.2  9.8  1.4  0.5  4.0  2.1  33.9          MVP-3,CPOY-6,AS,NBA1
# 2  2.7  8.8  11.5  6.5  1.2  1.1  3.4  2.9  30.4  MVP-4,DPOY-9,CPOY-12,AS,NBA1
# 3  0.9  4.7   5.5  6.2  2.0  0.9  2.2  2.5  30.1   MVP-2,DPOY-7,CPOY-3,AS,NBA1
# 4  0.6  3.1   3.6  6.7  0.9  0.2  2.4  1.9  28.7          MVP-5,CPOY-5,AS,NBA2
#
# [5 rows x 31 columns]

# %% [markdown]
# ### Com quais dados iremos lidar

# %%
dados.columns
# Out:
# Index(['Rk', 'Player', 'Age', 'Team', 'Pos', 'G', 'GS', 'MP', 'FG', 'FGA',
#        'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA',
#        'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS',
#        'Awards'],
#       dtype='object')

# %%
times = dados["Team"].drop_duplicates()
times.sort_values()
# Out:
# 26     2TM
# 137    3TM
# 15     ATL
# 7      BOS
# 37     BRK
# 20     CHI
# 22     CHO
# 9      CLE
# 1      DAL
# 11     DEN
# 31     DET
# 10     GSW
# 48     HOU
# 41     IND
# 24     LAC
# 14     LAL
# 17     MEM
# 28     MIA
# 2      MIL
# 12     MIN
# 30     NOP
# 4      NYK
# 3      OKC
# 32     ORL
# 0      PHI
# 5      PHO
# 34     POR
# 8      SAC
# 46     SAS
# 40     TOR
# 25     UTA
# 38     WAS
# Name: Team, dtype: object

# %% [markdown]
# ## Analise por times

# %% [markdown]
# ### Atlanta Falcons

# %%
atlanta = dados.loc[dados["Team"]=="ATL"]

# %%
atlanta.head()
# Out:
#      Rk             Player  Age Team Pos   G  GS    MP   FG   FGA  ...  ORB
# 15   16         Trae Young   25  ATL  PG  54  54  36.0  8.0  18.7  ...  0.4  \
# 36   35    Dejounte Murray   27  ATL  SG  78  78  35.7  8.6  18.8  ...  0.8
# 85   76  Bogdan Bogdanović   31  ATL  SG  79  33  30.4  6.0  13.9  ...  0.7
# 95   84      Jalen Johnson   22  ATL  SF  56  52  33.7  6.4  12.5  ...  1.3
# 101  90    De'Andre Hunter   26  ATL  SF  57  37  29.5  5.3  11.6  ...  0.5
#
#      DRB  TRB   AST  STL  BLK  TOV   PF   PTS  Awards
# 15   2.3  2.8  10.8  1.3  0.2  4.4  2.0  25.7      AS
# 36   4.5  5.3   6.4  1.4  0.3  2.6  1.8  22.5     NaN
# 85   2.8  3.4   3.1  1.2  0.3  1.4  2.3  16.9  6MOY-5
# 95   7.4  8.7   3.6  1.2  0.8  1.8  2.4  16.0     NaN
# 101  3.4  3.9   1.5  0.7  0.3  1.5  2.6  15.6     NaN
#
# [5 rows x 31 columns]

# %% [markdown]
# ### Pontuação

# %% [markdown]
# ### Mais pontos por jogo

# %%
lista_pontuacao = list(posicao.PTS)
lista_jogadores = list(posicao.Player)

plt.figure(figsize=(25,13))
plt.bar(lista_jogadores,lista_pontuacao)
for i in range(len(lista_pontuacao)):
    plt.text(i, lista_pontuacao[i] + 0.2, str(lista_pontuacao[i]), ha='center', fontsize=12)
plt.xlabel('Jogadores')
plt.ylabel('Pontos por jogo')
plt.title('Pontuação por jogo')
plt.show()

# %% [markdown]
# ### Maior % de acerto

# %%
lista_pontuacao = list(posicao["eFG%"])
lista_jogadores = list(posicao.Player)

plt.figure(figsize=(25,13))
plt.bar(lista_jogadores,lista_pontuacao)
for i in range(len(lista_pontuacao)):
    plt.text(i, lista_pontuacao[i]+0.01 , str(lista_pontuacao[i]), ha='center', fontsize=12)
plt.xlabel('Jogadores')
plt.ylabel('Pontos por jogo')
plt.title('Pontuação por jogo')
plt.show()

# %% [markdown]
# ### Chutes de 3

# %%
lista_jogadores = list(posicao.Player)
lista_3P = list(posicao["3P%"])
lista_3PA = list(posicao["3PA"])

# %%
lista_numeros = np.arange(0,1)
plt.figure(figsize=(25,13))
plt.scatter(lista_3PA,lista_3P)
for i in range(len(lista_3P)):
    plt.text(lista_3PA[i],lista_3P[i],str(lista_jogadores[i]),ha='center',va='top',fontsize=10)
    plt.text(lista_3PA[i],lista_3P[i],str(lista_3P[i]),ha='center',va='bottom',fontsize=10)

plt.xticks(np.arange(min(lista_3PA),max(lista_3PA),0.5))
plt.yticks(np.arange(min(lista_3P),max(lista_3P),0.1))
plt.xlabel('Tentativas por jogo')
plt.ylabel('% de Acerto')
plt.title('% de acertos por tentativas por jogo')
plt.show()

# %% [markdown]
# ### Chutes 2

# %%
lista_jogadores = list(posicao.Player)
lista_2P = list(posicao["2P%"])
lista_2PA = list(posicao["2PA"])

# %%
lista_numeros = np.arange(0,1)
plt.figure(figsize=(25,13))
plt.scatter(lista_2PA,lista_2P)
for i in range(len(lista_2P)):
    plt.text(lista_2PA[i],lista_2P[i],str(lista_jogadores[i]),ha='center',va='top',fontsize=10)
    plt.text(lista_2PA[i],lista_2P[i],str(lista_2P[i]),ha='center',va='bottom',fontsize=10)

plt.xticks(np.arange(min(lista_3PA),max(lista_3PA)+5,0.5))
plt.yticks(np.arange(min(lista_3P),max(lista_3P),0.1))
plt.xlabel('Tentativas por jogo')
plt.ylabel('% de Acerto')
plt.title('% de acertos por tentativas por jogo')
plt.show()

# %% [markdown]
# ### Minutagem

# %%
lista_minutagem = list(posicao.MP)
lista_jogadores = list(posicao.Player)

plt.figure(figsize=(25,13))
plt.bar(lista_jogadores,lista_minutagem)
for i in range(len(lista_minutagem)):
    plt.text(i, lista_minutagem[i] + 0.2, str(lista_minutagem[i]), ha='center', fontsize=12)
plt.xlabel('Jogadores')
plt.ylabel('Pontos por jogo')
plt.title('Minutagem por jogo')
plt.show()

# %% [markdown]
# ### Conclusões

# %% [markdown]
# Ao analisarmos o ataque do atlanta hawks podemos chegar a conclusão sobre a ineficiência de ter dejounte murray e trae young no ataque do time. Ambos os jogadores carregam com si um número extremamente alto de arremessos por partida, junto de uma eficiência que não é alta. Sendo assim necessário jogadores que pudessem complementar o time reduzindo a minutagem do trae, juntamente de jogadores que pudessem pontuar com uma carga menor de arremessos.
